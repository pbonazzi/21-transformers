# %% [markdown]
# # Transformers, what can they do?

# %% [markdown]
# Install the Transformers and Datasets libraries to run this notebook.

# %%
# !pip install datasets transformers[sentencepiece]
# Out:
# Collecting datasets
#   Downloading datasets-1.12.1-py3-none-any.whl (270 kB)
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.11.2-py3-none-any.whl (2.9 MB)
# Collecting dill
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting huggingface-hub<0.1.0,>=0.0.14
#   Downloading huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
# Collecting pandas
#   Downloading pandas-1.3.3-cp39-cp39-win_amd64.whl (10.2 MB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from datasets) (2.26.0)
# Collecting tqdm>=4.62.1
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Collecting pyarrow!=4.0.0,>=1.0.0
#   Downloading pyarrow-5.0.0-cp39-cp39-win_amd64.whl (14.5 MB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py39-none-any.whl (128 kB)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.10.0-py3-none-any.whl (125 kB)
# Requirement already satisfied: packaging in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from datasets) (21.0)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp39-cp39-win_amd64.whl (35 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from datasets) (1.21.2)
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp39-cp39-win_amd64.whl (634 kB)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Collecting filelock
#   Downloading filelock-3.3.0-py3-none-any.whl (9.7 kB)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
# Collecting regex!=2019.12.17
#   Downloading regex-2021.9.30-cp39-cp39-win_amd64.whl (273 kB)
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.96-cp39-cp39-win_amd64.whl (1.1 MB)
# Collecting protobuf
#   Downloading protobuf-3.18.0-cp39-cp39-win_amd64.whl (912 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->datasets) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->datasets) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->datasets) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->datasets) (2021.5.30)
# Requirement already satisfied: colorama in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp39-cp39-win_amd64.whl (125 kB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting chardet<5.0,>=2.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp39-cp39-win_amd64.whl (45 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\utente3\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)
# Collecting joblib
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting click
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Installing collected packages: multidict, yarl, typing-extensions, tqdm, regex, joblib, filelock, click, chardet, async-timeout, tokenizers, sacremoses, pyyaml, huggingface-hub, fsspec, dill, aiohttp, xxhash, transformers, sentencepiece, pyarrow, protobuf, pandas, multiprocess, datasets
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 chardet-4.0.0 click-8.0.1 datasets-1.12.1 dill-0.3.4 filelock-3.3.0 fsspec-2021.10.0 huggingface-hub-0.0.17 joblib-1.0.1 multidict-5.2.0 multiprocess-0.70.12.2 pandas-1.3.3 protobuf-3.18.0 pyarrow-5.0.0 pyyaml-5.4.1 regex-2021.9.30 sacremoses-0.0.46 sentencepiece-0.1.96 tokenizers-0.10.3 tqdm-4.62.3 transformers-4.11.2 typing-extensions-3.10.0.2 xxhash-2.0.2 yarl-1.6.3

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598047137260437}]

# %%
classifier([
    "I've been waiting for a HuggingFace course my whole life.", 
    "I hate this so much!"
])
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598047137260437},
#  {'label': 'NEGATIVE', 'score': 0.9994558095932007}]

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445963859558105, 0.111976258456707, 0.043427448719739914]}

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# [{'generated_text': 'In this course, we will teach you how to understand and use '
#                     'data flow and data interchange when handling user data. We '
#                     'will be working with one or more of the most commonly used '
#                     'data flows — data flows of various types, as seen by the '
#                     'HTTP'}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# [{'generated_text': 'In this course, we will teach you how to manipulate the world and '
#                     'move your mental and physical capabilities to your advantage.'},
#  {'generated_text': 'In this course, we will teach you how to become an expert and '
#                     'practice realtime, and with a hands on experience on both real '
#                     'time and real'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# [{'sequence': 'This course will teach you all about mathematical models.',
#   'score': 0.19619831442832947,
#   'token': 30412,
#   'token_str': ' mathematical'},
#  {'sequence': 'This course will teach you all about computational models.',
#   'score': 0.04052725434303284,
#   'token': 38163,
#   'token_str': ' computational'}]

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# [{'entity_group': 'PER', 'score': 0.99816, 'word': 'Sylvain', 'start': 11, 'end': 18},
#  {'entity_group': 'ORG', 'score': 0.97960, 'word': 'Hugging Face', 'start': 33, 'end': 45},
#  {'entity_group': 'LOC', 'score': 0.99321, 'word': 'Brooklyn', 'start': 49, 'end': 57}
# ]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn"
)
# Out:
# {'score': 0.6385916471481323, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer("""
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
""")
# Out:
# [{'summary_text': ' America has changed dramatically during recent years . The '
#                   'number of engineering graduates in the U.S. has declined in '
#                   'traditional engineering disciplines such as mechanical, civil '
#                   ', electrical, chemical, and aeronautical engineering . Rapidly '
#                   'developing economies such as China and India, as well as other '
#                   'industrial countries in Europe and Asia, continue to encourage '
#                   'and advance engineering .'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# [{'translation_text': 'This course is produced by Hugging Face.'}]
